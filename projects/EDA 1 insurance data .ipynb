# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\nobel'

# %%
os .chdir("C:/Users/nobel/OneDrive/Desktop/EDA and streamlit")

# %%
df = pd.read_csv("Insurance+Data+Analysis+Dataset.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
#To get sense ,if data frame is correct or not and get sense of dataset
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail(3)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
#Measure of central tendancy and dispersion 
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
Round_descriptive=df.describe().round(1)
Round_descriptive
# Out:
#           age     bmi  children  charges
# count  1338.0  1338.0    1338.0   1338.0
# mean     39.2    30.7       1.1  13270.4
# std      14.0     6.1       1.2  12110.0
# min      18.0    16.0       0.0   1121.9
# 25%      27.0    26.3       0.0   4740.3
# 50%      39.0    30.4       1.0   9382.0
# 75%      51.0    34.7       2.0  16639.9
# max      64.0    53.1       5.0  63770.4

# %%
#Percentile is very different from percentages , its used to rank student in competitive exam
#It says 25% of customer age is less than 27 or 27 . 50% percentile actualy median 
# The concept of std.dev is actually part of the concept of the shape of the distribution 
# symmetrical-mean, median , mode same . positive skewed-mean greater , negative skewed mode greater 
#Remember most of the statistical analysis demand normal distribution but in rela data folow skewness, This  challange mitigate 
#Law of large number, if the no of data point increase in data set , the distribution will tend towards normality
#for skewed understandking percentile is better than mean

# Low variation (mean plus minus std.dev) means low variation is actualy better
#outlier always skewed , we should either remove or transform the outlier , you can do it during transformation 
#Remember we cant avoid outliar fully , it always better to have few

# %%
#Histogram , find how many occurance is happen in range of bin 
import matplotlib.pyplot as plt
df.hist(bins= 25, figsize=(30,20))
plt.show()

# %%
#Insight: BMI folows symmetrical distrtribution 
#Charges follows skeweed distribution , its expected because charges depend on customer risk, foor understanding skewed , percentile help u better than mean
#Average will be highly misleading kin this case of skewed 
#can you say, BMI follow normal distribution , remember the condition , mean median and mode same and distribution should be symmetrical 
# in this case we only  see the symmetrical . dont know others , so u can not conclude , we can say only symmetrical at this point 
#histogram actually mapping frequency of distribution in visual

# %%
print(df.dtypes)
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# Boxplot use the concept of percentiles and concept of interquartile range(difference between 3rd and first quartile )
# calculat minimum and maximum by 1.5 times equation 
# outliar stay far from maximum and minimum , it can be asses fraud detection , product quality, service operation and sales
# when boxplot show outlier, do next set of analysis, ask the question why are u having outliar in first place
